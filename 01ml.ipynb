# %% [markdown]
# <a href="https://colab.research.google.com/github/zahratorki/calculator/blob/main/01ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/student-mat.csv", sep=";")
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

predict = "G3"

x = np.array(data.drop([predict], 1))
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)

accuracy = linear.score(x_test,y_test)
print("Model Accuracy: ", accuracy)

print("Coefficient: ", linear.coef_)
print("Intercept: ", linear.intercept_)

print("\n\n#####################################")
predictions = linear.predict(x_test)
for i in range(len(predictions)):
    print(f"Data #{i+1}")
    print("Model Prediction: ", predictions[i])
    print("Input Data: ", x_test[i])
    print("Real Label: ", y_test[i])
    print("#####################################")
# Out:
# Model Accuracy:  0.7977197720509156
# Coefficient:  [ 0.15371548  0.98329187 -0.11924142 -0.16882679  0.03328311]
# Intercept:  -1.6679636815435828
#
#
# #####################################
# Data #1
# Model Prediction:  8.307346882647604
# Input Data:  [ 8  8  1  0 30]
# Real Label:  8
# #####################################
# Data #2
# Model Prediction:  12.123147907131118
# Input Data:  [12 12  1  0  8]
# Real Label:  12
# #####################################
# Data #3
# Model Prediction:  5.202445462203705
# Input Data:  [7 6 2 0 4]
# Real Label:  6
# #####################################
# Data #4
# Model Prediction:  4.0654381164423326
# Input Data:  [6 5 2 0 4]
# Real Label:  6
# #####################################
# Data #5
# Model Prediction:  10.580051237828664
# Input Data:  [10 11  2  0  4]
# Real Label:  9
# #####################################
# Data #6
# Model Prediction:  -0.5230072284663687
# Input Data:  [9 0 2 0 0]
# Real Label:  0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
